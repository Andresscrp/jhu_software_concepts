# %%
from pathlib import Path
from src.s3_fetch import download_applicant_data

download_applicant_data(
    bucket_name="grad-cafe",
    object_key="applicant_data.json",
    output_path=Path("applicant_data_SM.json")
)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[1], line 4
#       1 from pathlib import Path
#       2 from src.s3_fetch import download_applicant_data
# ----> 4 download_applicant_data(
#       5     bucket_name="grad-cafe",
#       6     object_key="applicant_data.json",
#       7     output_path=Path("applicant_data_SM.json")
#       8 )
#
# File d:\School\JHU\Modern Softwaree Concepts in Python\code\jhu_software_concepts\module_7\src\s3_fetch.py:41, in download_applicant_data(bucket_name, object_key, output_path)
#      37 s3_client = boto3.client("s3")
#      39 output_path.parent.mkdir(parents=True, exist_ok=True)
# ---> 41 s3_client.download_file(
#      42     bucket_name,
#      43     object_key,
#      44     str(output_path),
#      45 )
#      47 print(f"Downloaded s3://{bucket_name}/{object_key} -> {output_path}")
#
# ...

# %%
# !pip install boto3
# Out:
# ...
#   Using cached boto3-1.42.61-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached botocore-1.42.61-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# ...
# Using cached boto3-1.42.61-py3-none-any.whl (140 kB)
# Using cached botocore-1.42.61-py3-none-any.whl (14.6 MB)
# Using cached jmespath-1.1.0-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
